# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="F3uk10NQiUxTuevzrZeq")
project = rf.workspace("yes-workspace-0buvc").project("uav-f44in-bhrcv")
version = project.version(5)
dataset = version.download("yolo26")
# Out:
# Requirement already satisfied: roboflow in ./.venv/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.11/site-packages (from roboflow) (2026.2.25)
# Requirement already satisfied: idna==3.7 in ./.venv/lib/python3.11/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in ./.venv/lib/python3.11/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.11/site-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.11/site-packages (from roboflow) (3.10.8)
# Requirement already satisfied: numpy>=1.18.5 in ./.venv/lib/python3.11/site-packages (from roboflow) (2.4.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in ./.venv/lib/python3.11/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in ./.venv/lib/python3.11/site-packages (from roboflow) (12.2.0)
# Requirement already satisfied: pi-heif<2 in ./.venv/lib/python3.11/site-packages (from roboflow) (1.3.0)
# Requirement already satisfied: pillow-avif-plugin<2 in ./.venv/lib/python3.11/site-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.11/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.11/site-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in ./.venv/lib/python3.11/site-packages (from roboflow) (2.33.1)
# Requirement already satisfied: six in ./.venv/lib/python3.11/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in ./.venv/lib/python3.11/site-packages (from roboflow) (2.6.3)
# Requirement already satisfied: tqdm>=4.41.0 in ./.venv/lib/python3.11/site-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in ./.venv/lib/python3.11/site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in ./.venv/lib/python3.11/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in ./.venv/lib/python3.11/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer>=0.12.0 in ./.venv/lib/python3.11/site-packages (from roboflow) (0.24.1)
# Requirement already satisfied: click>=8.2.1 in ./.venv/lib/python3.11/site-packages (from typer>=0.12.0->roboflow) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.11/site-packages (from typer>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in ./.venv/lib/python3.11/site-packages (from typer>=0.12.0->roboflow) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./.venv/lib/python3.11/site-packages (from typer>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib->roboflow) (4.62.1)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.11/site-packages (from matplotlib->roboflow) (26.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.11/site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests->roboflow) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.11/site-packages (from rich>=12.3.0->typer>=0.12.0->roboflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.11/site-packages (from rich>=12.3.0->typer>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.12.0->roboflow) (0.1.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in UAV--5 to yolo26:: 100%|██████████| 3712/3712 [00:01<00:00, 2726.59it/s]
# Extracting Dataset Version Zip to UAV--5 in yolo26:: 100%|██████████| 78/78 [00:00<00:00, 10608.51it/s]
